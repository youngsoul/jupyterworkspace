# %% [markdown]
# ## Decision Forest Regression
#
# Based on the AzureML Experiment:  Decision Forest Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, accuracy_score
from sklearn.linear_model import Ridge
from scipy.stats import spearmanr, pearsonr

# %% [markdown]
# You are provided hourly rental data spanning two years. For this competition, the training set is comprised of the first 19 days of each month, while the test set is the 20th to the end of the month. You must predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.
#
# Data Fields
#
# datetime - hourly date + timestamp
#
# season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
#
# holiday - whether the day is considered a holiday
#
# workingday - whether the day is neither a weekend nor holiday
#
# weather - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# temp - temperature in Celsius
#
# atemp - "feels like" temperature in Celsius
#
# humidity - relative humidity
#
# windspeed - wind speed
#
# casual - number of non-registered user rentals initiated
#
# registered - number of registered user rentals initiated
#
# count - number of total rentals
#
# [Link to DataSet](https://www.kaggle.com/c/bike-sharing-demand/data)

# %%
df = pd.read_csv('./data/azureml/Bike_Rental_UCI_dataset.csv')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.shape
# Out:
# (17379, 17)

# %%
def day_of_week():  
    ## First day in the dataset is Saturday
    days = pd.DataFrame([[0, 1, 2, 3, 4, 5, 6],
      ["Sun", "Mon", "Tue", "Wed", "Thr", "Fri", "Sat"]]).transpose()
    days.columns = ['weekday', 'dayOfWeek']                        
    return days

# %%
days_df = day_of_week()
days_df.head()
# Out:
#   weekday dayOfWeek
# 0       0       Sun
# 1       1       Mon
# 2       2       Tue
# 3       3       Wed
# 4       4       Thr

# %%
df = pd.merge(df, days_df, on='weekday', how='outer')
df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0       6           0
# 1        2  2011-01-01       1   0     1   1        0       6           0
# 2        3  2011-01-01       1   0     1   2        0       6           0
# 3        4  2011-01-01       1   0     1   3        0       6           0
# 4        5  2011-01-01       1   0     1   4        0       6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1
#
#   dayOfWeek
# 0       Sat
# 1       Sat
# 2       Sat
# 3       Sat
# 4       Sat

# %%
df.shape
# Out:
# (17379, 18)

# %%
# determine the number of integer days since the first record.
def set_days(df):  
    import pandas as pd
    df['days'] = pd.Series(range(df.shape[0]))/24
    df['days'] = df['days'].astype('int')
    return df

# %%
set_days(df)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday weekday  workingday  \
# 0            1  2011-01-01       1   0     1   0        0       6           0
# 1            2  2011-01-01       1   0     1   1        0       6           0
# 2            3  2011-01-01       1   0     1   2        0       6           0
# 3            4  2011-01-01       1   0     1   3        0       6           0
# 4            5  2011-01-01       1   0     1   4        0       6           0
# 5            6  2011-01-01       1   0     1   5        0       6           0
# 6            7  2011-01-01       1   0     1   6        0       6           0
# 7            8  2011-01-01       1   0     1   7        0       6           0
# 8            9  2011-01-01       1   0     1   8        0       6           0
# 9           10  2011-01-01       1   0     1   9        0       6           0
# 10          11  2011-01-01       1   0     1  10        0       6           0
# 11          12  2011-01-01       1   0     1  11        0       6           0
# 12          13  2011-01-01       1   0     1  12        0       6           0
# 13          14  2011-01-01       1   0     1  13        0       6           0
# 14          15  2011-01-01       1   0     1  14        0       6           0
# 15          16  2011-01-01       1   0     1  15        0       6           0
# 16          17  2011-01-01       1   0     1  16        0       6           0
# 17          18  2011-01-01       1   0     1  17        0       6           0
# 18          19  2011-01-01       1   0     1  18        0       6           0
# 19          20  2011-01-01       1   0     1  19        0       6           0
# 20          21  2011-01-01       1   0     1  20        0       6           0
# 21          22  2011-01-01       1   0     1  21        0       6           0
# 22          23  2011-01-01       1   0     1  22        0       6           0
# 23          24  2011-01-01       1   0     1  23        0       6           0
# 24         162  2011-01-08       1   0     1   0        0       6           0
# 25         163  2011-01-08       1   0     1   1        0       6           0
# 26         164  2011-01-08       1   0     1   2        0       6           0
# 27         165  2011-01-08       1   0     1   3        0       6           0
# 28         166  2011-01-08       1   0     1   4        0       6           0
# 29         167  2011-01-08       1   0     1   5        0       6           0
# ...        ...         ...     ...  ..   ...  ..      ...     ...         ...
# 17349    17136  2012-12-21       1   1    12  18        0       5           1
# 17350    17137  2012-12-21       1   1    12  19        0       5           1
# 17351    17138  2012-12-21       1   1    12  20        0       5           1
# 17352    17139  2012-12-21       1   1    12  21        0       5           1
# 17353    17140  2012-12-21       1   1    12  22        0       5           1
# 17354    17141  2012-12-21       1   1    12  23        0       5           1
# 17355    17284  2012-12-28       1   1    12   0        0       5           1
# 17356    17285  2012-12-28       1   1    12   1        0       5           1
# 17357    17286  2012-12-28       1   1    12   2        0       5           1
# 17358    17287  2012-12-28       1   1    12   3        0       5           1
# 17359    17288  2012-12-28       1   1    12   4        0       5           1
# 17360    17289  2012-12-28       1   1    12   5        0       5           1
# 17361    17290  2012-12-28       1   1    12   6        0       5           1
# 17362    17291  2012-12-28       1   1    12   7        0       5           1
# 17363    17292  2012-12-28       1   1    12   8        0       5           1
# 17364    17293  2012-12-28       1   1    12   9        0       5           1
# 17365    17294  2012-12-28       1   1    12  10        0       5           1
# 17366    17295  2012-12-28       1   1    12  11        0       5           1
# 17367    17296  2012-12-28       1   1    12  12        0       5           1
# 17368    17297  2012-12-28       1   1    12  13        0       5           1
# 17369    17298  2012-12-28       1   1    12  14        0       5           1
# 17370    17299  2012-12-28       1   1    12  15        0       5           1
# 17371    17300  2012-12-28       1   1    12  16        0       5           1
# 17372    17301  2012-12-28       1   1    12  17        0       5           1
# 17373    17302  2012-12-28       1   1    12  18        0       5           1
# 17374    17303  2012-12-28       1   1    12  19        0       5           1
# 17375    17304  2012-12-28       1   1    12  20        0       5           1
# 17376    17305  2012-12-28       1   1    12  21        0       5           1
# 17377    17306  2012-12-28       1   1    12  22        0       5           1
# 17378    17307  2012-12-28       1   1    12  23        0       5           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# 0               1  0.24  0.2879  0.81     0.0000       3          13   16
# 1               1  0.22  0.2727  0.80     0.0000       8          32   40
# 2               1  0.22  0.2727  0.80     0.0000       5          27   32
# 3               1  0.24  0.2879  0.75     0.0000       3          10   13
# 4               1  0.24  0.2879  0.75     0.0000       0           1    1
# 5               2  0.24  0.2576  0.75     0.0896       0           1    1
# 6               1  0.22  0.2727  0.80     0.0000       2           0    2
# 7               1  0.20  0.2576  0.86     0.0000       1           2    3
# 8               1  0.24  0.2879  0.75     0.0000       1           7    8
# 9               1  0.32  0.3485  0.76     0.0000       8           6   14
# 10              1  0.38  0.3939  0.76     0.2537      12          24   36
# 11              1  0.36  0.3333  0.81     0.2836      26          30   56
# 12              1  0.42  0.4242  0.77     0.2836      29          55   84
# 13              2  0.46  0.4545  0.72     0.2985      47          47   94
# 14              2  0.46  0.4545  0.72     0.2836      35          71  106
# 15              2  0.44  0.4394  0.77     0.2985      40          70  110
# 16              2  0.42  0.4242  0.82     0.2985      41          52   93
# 17              2  0.44  0.4394  0.82     0.2836      15          52   67
# 18              3  0.42  0.4242  0.88     0.2537       9          26   35
# 19              3  0.42  0.4242  0.88     0.2537       6          31   37
# 20              2  0.40  0.4091  0.87     0.2537      11          25   36
# 21              2  0.40  0.4091  0.87     0.1940       3          31   34
# 22              2  0.40  0.4091  0.94     0.2239      11          17   28
# 23              2  0.46  0.4545  0.88     0.2985      15          24   39
# 24              2  0.18  0.1970  0.51     0.1642       1          24   25
# 25              2  0.18  0.2121  0.55     0.0896       1          15   16
# 26              2  0.18  0.2424  0.55     0.0000       3          13   16
# 27              3  0.18  0.1970  0.55     0.1642       0           7    7
# 28              3  0.18  0.1970  0.55     0.1642       0           1    1
# 29              2  0.16  0.1667  0.74     0.1642       0           5    5
# ...           ...   ...     ...   ...        ...     ...         ...  ...
# 17349           2  0.26  0.2273  0.56     0.2985       7         236  243
# 17350           1  0.28  0.2576  0.45     0.2985       5         148  153
# 17351           1  0.28  0.2727  0.41     0.2537       8         104  112
# 17352           1  0.26  0.2273  0.41     0.4179       2          68   70
# 17353           1  0.26  0.2273  0.44     0.2985       6          57   63
# 17354           1  0.26  0.2424  0.44     0.2836       1          39   40
# 17355           2  0.24  0.2424  0.60     0.1642       3          22   25
# 17356           1  0.24  0.2273  0.60     0.1940       0           9    9
# 17357           1  0.24  0.2273  0.60     0.2537       0           5    5
# 17358           2  0.24  0.2424  0.60     0.1642       0           2    2
# 17359           2  0.24  0.2576  0.60     0.1045       0           4    4
# 17360           2  0.24  0.2576  0.60     0.0896       0          15   15
# 17361           1  0.22  0.2121  0.64     0.2836       2          49   51
# 17362           1  0.22  0.2273  0.64     0.1642       1         111  112
# 17363           2  0.24  0.2424  0.60     0.1343       1         238  239
# 17364           2  0.24  0.2121  0.60     0.2836      18         173  191
# 17365           2  0.26  0.2424  0.56     0.2537      77          85  162
# 17366           2  0.28  0.2727  0.52     0.2239      71         107  178
# 17367           2  0.30  0.3030  0.49     0.1343      72         150  222
# 17368           2  0.30  0.3030  0.49     0.1343      76         146  222
# 17369           2  0.30  0.3030  0.49     0.1343      84         177  261
# 17370           2  0.30  0.3182  0.49     0.0000      74         151  225
# 17371           1  0.30  0.3030  0.49     0.1343      42         208  250
# 17372           1  0.24  0.2424  0.60     0.1343      43         228  271
# 17373           1  0.24  0.2424  0.60     0.1343      16         197  213
# 17374           2  0.24  0.2273  0.65     0.1940      15         113  128
# 17375           2  0.24  0.2576  0.65     0.1045      14          83   97
# 17376           2  0.24  0.2424  0.70     0.1343      17          75   92
# 17377           2  0.24  0.2576  0.70     0.0896      13          49   62
# 17378           2  0.24  0.2576  0.65     0.0896       5          54   59
#
#       dayOfWeek  days
# 0           Sat     0
# 1           Sat     0
# 2           Sat     0
# 3           Sat     0
# 4           Sat     0
# 5           Sat     0
# 6           Sat     0
# 7           Sat     0
# 8           Sat     0
# 9           Sat     0
# 10          Sat     0
# 11          Sat     0
# 12          Sat     0
# 13          Sat     0
# 14          Sat     0
# 15          Sat     0
# 16          Sat     0
# 17          Sat     0
# 18          Sat     0
# 19          Sat     0
# 20          Sat     0
# 21          Sat     0
# 22          Sat     0
# 23          Sat     0
# 24          Sat     1
# 25          Sat     1
# 26          Sat     1
# 27          Sat     1
# 28          Sat     1
# 29          Sat     1
# ...         ...   ...
# 17349       Fri   722
# 17350       Fri   722
# 17351       Fri   722
# 17352       Fri   723
# 17353       Fri   723
# 17354       Fri   723
# 17355       Fri   723
# 17356       Fri   723
# 17357       Fri   723
# 17358       Fri   723
# 17359       Fri   723
# 17360       Fri   723
# 17361       Fri   723
# 17362       Fri   723
# 17363       Fri   723
# 17364       Fri   723
# 17365       Fri   723
# 17366       Fri   723
# 17367       Fri   723
# 17368       Fri   723
# 17369       Fri   723
# 17370       Fri   723
# 17371       Fri   723
# 17372       Fri   723
# 17373       Fri   723
# 17374       Fri   723
# 17375       Fri   723
# 17376       Fri   724
# 17377       Fri   724
# 17378       Fri   724
#
# [17379 rows x 19 columns]

# %%
# remove some of the columns that do not appear to be useful
df.drop(columns=['instant', 'dteday', 'atemp', 'casual', 'registered', 'weekday'], inplace=True)
df.head()
# Out:
#    season  yr  mnth  hr  holiday  workingday  weathersit  temp   hum  \
# 0       1   0     1   0        0           0           1  0.24  0.81
# 1       1   0     1   1        0           0           1  0.22  0.80
# 2       1   0     1   2        0           0           1  0.22  0.80
# 3       1   0     1   3        0           0           1  0.24  0.75
# 4       1   0     1   4        0           0           1  0.24  0.75
#
#    windspeed  cnt dayOfWeek  days
# 0        0.0   16       Sat     0
# 1        0.0   40       Sat     0
# 2        0.0   32       Sat     0
# 3        0.0   13       Sat     0
# 4        0.0    1       Sat     0

# %%
df.describe()
# Out:
#              season            yr          mnth            hr       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#          workingday    weathersit          temp           hum     windspeed  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.682721      1.425283      0.496987      0.627229      0.190098
# std        0.465431      0.639357      0.192556      0.192930      0.122340
# min        0.000000      1.000000      0.020000      0.000000      0.000000
# 25%        0.000000      1.000000      0.340000      0.480000      0.104500
# 50%        1.000000      1.000000      0.500000      0.630000      0.194000
# 75%        1.000000      2.000000      0.660000      0.780000      0.253700
# max        1.000000      4.000000      1.000000      1.000000      0.850700
#
#                 cnt          days
# count  17379.000000  17379.000000
# mean     189.463088    361.562576
# std      181.387599    209.042828
# min        1.000000      0.000000
# 25%       40.000000    181.000000
# 50%      142.000000    362.000000
# 75%      281.000000    543.000000
# max      977.000000    724.000000

# %%
# normalize 
scaler = StandardScaler()
df['temp_scaled'] = scaler.fit_transform(df['temp'].values.reshape(-1,1))
df['hum_scaled'] = scaler.fit_transform(df['hum'].values.reshape(-1,1))
df['windspeed_scaled'] = scaler.fit_transform(df['windspeed'].values.reshape(-1,1))

df.head()
# Out:
#    season  yr  mnth  hr  holiday  workingday  weathersit  temp   hum  \
# 0       1   0     1   0        0           0           1  0.24  0.81
# 1       1   0     1   1        0           0           1  0.22  0.80
# 2       1   0     1   2        0           0           1  0.22  0.80
# 3       1   0     1   3        0           0           1  0.24  0.75
# 4       1   0     1   4        0           0           1  0.24  0.75
#
#    windspeed  cnt dayOfWeek  days  temp_scaled  hum_scaled  windspeed_scaled
# 0        0.0   16       Sat     0    -1.334648    0.947372         -1.553889
# 1        0.0   40       Sat     0    -1.438516    0.895539         -1.553889
# 2        0.0   32       Sat     0    -1.438516    0.895539         -1.553889
# 3        0.0   13       Sat     0    -1.334648    0.636370         -1.553889
# 4        0.0    1       Sat     0    -1.334648    0.636370         -1.553889

# %%
X = df.drop(columns=['cnt','dayOfWeek'])
y = df['cnt']
print(X.shape)
print(y.shape)
# Out:
# (17379, 14)
# (17379,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, test_size=0.3, random_state=123)

# %% [markdown]
# # Random Forest Regressor

# %%
model = RandomForestRegressor(n_estimators=100, oob_score=True, random_state=0, max_depth=32, min_samples_leaf=1)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=32,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=True, random_state=0, verbose=0, warm_start=False)

# %%
predicted_train = model.predict(X_train)
y_predicted_test = model.predict(X_test)

test_score = r2_score(y_test, y_predicted_test)
spearman = spearmanr(y_test, y_predicted_test)
pearson = pearsonr(y_test, y_predicted_test)

print(f'Out-of-bag R-2 score estimate: {model.oob_score_:>5.3}')
print(f'Test data R-2 score: {test_score:>5.3}')
print(f'Test data Spearman correlation: {spearman[0]:.3}')
print(f'Test data Pearson correlation: {pearson[0]:.3}')
# Out:
# Out-of-bag R-2 score estimate:  0.94
# Test data R-2 score: 0.945
# Test data Spearman correlation: 0.974
# Test data Pearson correlation: 0.972

# %%
model.score(X_test, y_test)
# Out:
# 0.9448512912389737

# %%
print(X.columns)
print(model.feature_importances_)
# Out:
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'workingday', 'weathersit',
#        'temp', 'hum', 'windspeed', 'days', 'temp_scaled', 'hum_scaled',
#        'windspeed_scaled'],
#       dtype='object')
# [0.02114194 0.08041103 0.01420437 0.60580258 0.00182017 0.03644419
#  0.01537652 0.07116447 0.01410447 0.00533042 0.0506552  0.06381953
#  0.01437006 0.00535507]

# %% [markdown]
# # Ridge Linear Regression Model
#
# Compare the Decision Forest Regressor with the Ridge Linear Regression Model

# %%
lr_model = Ridge(alpha=0.001, random_state=123)

# %%
lr_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=123, solver='auto', tol=0.001)

# %%
lr_predicted_train = lr_model.predict(X_train)
lr_y_predicted_test = lr_model.predict(X_test)

lr_test_score = r2_score(y_test, lr_y_predicted_test)
lr_spearman = spearmanr(y_test, lr_y_predicted_test)
lr_pearson = pearsonr(y_test, lr_y_predicted_test)

print(f'Test data R-2 score: {lr_test_score:>5.3}')
print(f'Test data Spearman correlation: {lr_spearman[0]:.3}')
print(f'Test data Pearson correlation: {lr_pearson[0]:.3}')
# Out:
# Test data R-2 score: 0.388
# Test data Spearman correlation: 0.685
# Test data Pearson correlation: 0.624

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.38822576602206327
